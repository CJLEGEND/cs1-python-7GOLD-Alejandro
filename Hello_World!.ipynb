# %% [markdown]
# <a href="https://colab.research.google.com/github/CJLEGEND/cs1-python-7GOLD-Alejandro/blob/main/Hello_World!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world from Cejian!")
# Out:
# Hello world from Cejian!
