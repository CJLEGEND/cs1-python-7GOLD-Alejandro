# %% [markdown]
# <a href="https://colab.research.google.com/github/CJLEGEND/cs1-python-7GOLD-Alejandro/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

if num1 >= num2 and num1 >= num3:
  print ("The largest number is: ",num1)

elif num1 <= num2 and num2 >= num3:
    print ("The largest number is: ",num2)

else:
  print ("The largest number is: ", num3)
# Out:
# Enter the first number: 12
# Enter the second number: 56
# Enter the third number: 43
# The largest number is:  56
